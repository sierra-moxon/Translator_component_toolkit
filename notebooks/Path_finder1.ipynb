# %% [markdown]
# ## Path Finder: What are the potential paths between two nodes?
# ## This pipeline can be used to get a ranked path between A and B given a set of paths.
#
# ![image.png](attachment:3da53daa-b927-420f-8b64-97ee4046cc60.png)
#
# Example questions:
#
# What drugs may treat ovarian cancer (MONDO:0008170) patients with BRCA1 mutation?
#
# What is the mechanism of Olaparib being effective for patients with BRCA1 mutation?

# %%
# include path ../src in order to import modules
import sys
sys.path.append('../src')
import TCT as TCT
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import ipywidgets as widgets

# %%
# Step1: List all the APIs in the translator system
APInames = TCT.list_Translator_APIs()
print(len(APInames))
#print(APInames.keys())

# Step 2: Get metaKG and all predicates from Translator APIs
#metaKG = TCT.get_KP_metadata(APInames) # This only applies to the Translator APIs
#print(metaKG.columns)
#print(metaKG.shape)

#metaKG.to_csv('../metaData/metaKG.csv', index=False)
metaKG = pd.read_csv('../metaData/metaKG.csv')
All_predicates = list(set(metaKG['KG_category']))
All_categories = list((set(list(set(metaKG['Subject']))+list(set(metaKG['Object'])))))
# Out:
# 98

# %%
#### The following use case is to fine the Genes or proteins that connect the gene BRCA2 and the drug Olaparib

# %%
# Step 3: set input parameters

# Node1 for query
input_node1 = 'BRCA2'
input_node1_id = TCT.get_curie(input_node1)
print(input_node1_id)
input_node1_list = [input_node1_id]
input_node1_category = ['biolink:Gene'] # Node: this has to be in a format of biolink:xxx

#Node2 for query
input_node2_list = []
#input_node2_category = ['biolink:Drug','biolink:SmallMolecule'] # Node: this has to be in a format of biolink:xxx
input_node2_category = ['biolink:Gene','biolink:Protein'] # Node: this has to be in a format of biolink:xxx


# Get all predicates for the input node1 and node2, user can furter select the predicates among this list
sele_predicates = list(set(TCT.select_concept(sub_list=input_node1_category,
                                              obj_list=input_node2_category,
                                              metaKG=metaKG)))

print("all relevant predicates in Translator:")
print(sele_predicates)
# select predicates

# Get all APIs for the input node1 and node2, user can furter select the APIs among this list
sele_APIs_1 = TCT.select_API(sub_list=input_node1_category,
                             obj_list=input_node2_category,
                             metaKG=metaKG)
print("all relevant APIs in Translator:")
print(sele_APIs_1)

# get API URLs
API_URLs_1 = TCT.get_Translator_API_URL(sele_APIs_1, APInames)

#---------------------------------------------------------------------------------------------------------------------------------#

# Node3 for query
#input_node3 = 'Ovarian cancer'
input_node3 = "Olaparib"
input_node3_id = TCT.get_curie(input_node3)
print(input_node3_id)
#input_node3_id = "MONDO:0008170" # have to change UMLS to MONDO ids
input_node3_list = [input_node3_id]
input_node3_category = ['biolink:SmallMolecule', 'biolink:Drug','biolink:ChemicalSubstance'] # Node: this has to be in a format of biolink:xxx
#input_node3_category = ['biolink:Disease']

# Get all predicates for the input node1 and node2, user can furter select the predicates among this list
sele_predicates_2 = list(set(TCT.select_concept(sub_list=input_node3_category,
                                                obj_list=input_node2_category,
                                                metaKG=metaKG)))
print("all relevant predicates in Translator:")
print(sele_predicates_2)
# select predicates

# Get all APIs for the input node1 and node2, user can furter select the APIs among this list
sele_APIs_2 = TCT.select_API(sub_list=input_node3_category,
                             obj_list=input_node2_category,
                             metaKG=metaKG)
print("all relevant APIs in Translator:")
print(sele_APIs_2)

# get API URLs
API_URLs_2 = TCT.get_Translator_API_URL(sele_APIs_2, 
                                      APInames)
# Out:
# NCBIGene:675
# all relevant predicates in Translator:
# ['biolink:regulates', 'biolink:regulated_by', 'biolink:orthologous_to', 'biolink:contributes_to', 'biolink:produced_by', 'biolink:related_to', 'biolink:affects', 'biolink:homologous_to', 'biolink:genetically_interacts_with', 'biolink:interacts_with', 'biolink:negatively_correlated_with', 'biolink:close_match', 'biolink:has_input', 'biolink:positively_correlated_with', 'biolink:has_phenotype', 'biolink:coexists_with', 'biolink:derives_from', 'biolink:gene_product_of', 'biolink:has_part', 'biolink:physically_interacts_with', 'biolink:biomarker_for', 'biolink:directly_physically_interacts_with', 'biolink:coexpressed_with', 'biolink:part_of', 'biolink:derives_into', 'biolink:causes', 'biolink:subclass_of', 'biolink:genetically_associated_with', 'biolink:binds', 'biolink:affected_by', 'biolink:correlated_with', 'biolink:produces', 'biolink:genetic_association', 'biolink:has_gene_product']
# all relevant APIs in Translator:
# ['Automat-gtex(Trapi v1.4.0)', 'MolePro', 'Service Provider TRAPI', 'Automat-biolink(Trapi v1.4.0)', 'Automat-hmdb(Trapi v1.4.0)', 'Multiomics BigGIM-DrugResponse KP API', 'BioThings Explorer (BTE) TRAPI', 'Automat-hgnc(Trapi v1.4.0)', 'SPOKE KP for TRAPI 1.4', 'Biothings Explorer (BTE)', 'Automat-gwas-catalog(Trapi v1.4.0)', 'MyGene.info API', 'BioThings SEMMEDDB API', 'Translator Annotation Service', 'BioLink API', 'Automat-icees-kg(Trapi v1.4.0)', 'Automat-sri-reference-kg(Trapi v1.4.0)', 'Automat-ubergraph-nonredundant(Trapi v1.4.0)', 'Automat-pharos(Trapi v1.4.0)', 'imProving Agent for TRAPI 1.4', 'Text Mining Targeted Association API', 'Automat-robokop(Trapi v1.4.0)', 'Agrkb(Trapi v1.4.0)', 'Automat-panther(Trapi v1.4.0)', 'Automat-sri-reference-kp(Trapi v1.4.0)', 'Automat-ctd(Trapi v1.4.0)', 'PharmGKB REST API', 'Automat-ubergraph(Trapi v1.4.0)', 'Automat-hetio(Trapi v1.4.0)', 'Automat-gtopdb(Trapi v1.4.0)', 'Automat-cam-kp(Trapi v1.4.0)']
# PUBCHEM.COMPOUND:23725625
# all relevant predicates in Translator:
# ['biolink:regulates', 'biolink:associated_with_sensitivity_to', 'biolink:overlaps', 'biolink:affects_response_to', 'biolink:related_to', 'biolink:produced_by', 'biolink:affects', 'biolink:is_assessed_by', 'biolink:sensitivity_associated_with', 'biolink:interacts_with', 'biolink:negatively_correlated_with', 'biolink:associated_with_resistance_to', 'biolink:positively_correlated_with', 'biolink:treats', 'biolink:coexists_with', 'biolink:assesses', 'biolink:derives_from', 'biolink:gene_product_of', 'biolink:resistance_associated_with', 'biolink:has_part', 'biolink:response_affected_by', 'biolink:disrupted_by', 'biolink:physically_interacts_with', 'biolink:directly_physically_interacts_with', 'biolink:part_of', 'biolink:disrupts', 'biolink:occurs_together_in_literature_with', 'biolink:derives_into', 'biolink:has_substrate', 'biolink:subclass_of', 'biolink:genetically_associated_with', 'biolink:causes', 'biolink:binds', 'biolink:is_substrate_of', 'biolink:affected_by', 'biolink:correlated_with', 'biolink:produces', 'biolink:increases_response_to', 'biolink:decreases_response_to', 'biolink:genetic_association', 'biolink:has_gene_product']
# all relevant APIs in Translator:
# ['Automat-drug-central(Trapi v1.4.0)', 'Text Mined Cooccurrence API', 'BioThings DGIdb API', 'MolePro', 'Service Provider TRAPI', 'Automat-biolink(Trapi v1.4.0)', 'Automat-hmdb(Trapi v1.4.0)', 'Multiomics BigGIM-DrugResponse KP API', 'BioThings PFOCR API', 'BioThings BindingDB API', 'MyChem.info API', 'BioThings Explorer (BTE) TRAPI', 'Biothings Explorer (BTE)', 'BioThings SEMMEDDB API', 'Translator Annotation Service', 'Automat-icees-kg(Trapi v1.4.0)', 'Automat-ubergraph-nonredundant(Trapi v1.4.0)', 'Automat-pharos(Trapi v1.4.0)', 'Text Mining Targeted Association API', 'Automat-robokop(Trapi v1.4.0)', 'Automat-ctd(Trapi v1.4.0)', 'PharmGKB REST API', 'Automat-ubergraph(Trapi v1.4.0)', 'CTD API', 'Multiomics Wellness KP API', 'Automat-hetio(Trapi v1.4.0)', 'Automat-gtopdb(Trapi v1.4.0)', 'Automat-cam-kp(Trapi v1.4.0)']

# %%
# Step 4: Format query json
query_json = TCT.format_query_json(input_node1_list,  # a list of identifiers for input node1
                                   input_node2_list,  # it can be empty list if only want to query node1
                                   input_node1_category,  # a list of categories of input node1
                                   input_node2_category,  # a list of categories of input node2
                                   sele_predicates) # a list of predicates
# Step 5: Query Translator APIs and parse results
result = TCT.parallel_api_query(API_URLs_1,query_json=query_json, max_workers=len(API_URLs_1))
# Step 6: Parse results
result_parsed = TCT.parse_KG(result)
# Step 7: Ranking the results. This ranking method is based on the number of unique primary infores. It can only be used to rank the results with one defined node.
result_ranked_by_primary_infores = TCT.rank_by_primary_infores(result_parsed, input_node1_id)   # input_node1_id is the curie id of the input node, such as "NCBIGene:672"
# Out:
# '' generated an exception: Invalid URL '': No scheme supplied. Perhaps you meant https://?
# '' generated an exception: Invalid URL '': No scheme supplied. Perhaps you meant https://?
# '' generated an exception: Invalid URL '': No scheme supplied. Perhaps you meant https://?
# '' generated an exception: Invalid URL '': No scheme supplied. Perhaps you meant https://?
# '' generated an exception: Invalid URL '': No scheme supplied. Perhaps you meant https://?
# '' generated an exception: Invalid URL '': No scheme supplied. Perhaps you meant https://?
# Warning Code:404:https://api.bte.ncats.io/v1/bde72db681ec0b8f9eeb67bb6b8dd72c/query
# Warning Code:405:https://automat.renci.org/gtex/1.4/query
# Warning Code:405:https://automat.renci.org/hgnc/1.4/query
# Warning Code:404:https://automat.renci.org/biolink/1.4/query
# Warning Code:503:https://bte.test.transltr.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query
# Warning Code:405:https://automat.renci.org/icees-kg/1.4/queryWarning Code:405:https://automat.renci.org/gtopdb/1.4/queryWarning Code:405:https://automat.renci.org/hmdb/1.4/queryWarning Code:405:https://automat.renci.org/panther/1.4/queryWarning Code:405:https://automat.renci.org/gwas-catalog/1.4/query
#
#
#
#
# Warning Code:405:https://automat.renci.org/pharos/1.4/query
# Warning Code:500:https://spokekp.transltr.io/api/v1.4/query
# Success!https://automat.transltr.io/genome-alliance/1.4/query
# Warning Code:404:https://automat.ci.transltr.io/sri-reference-kp/1.4/query
# Warning Code:404:https://automat.ci.transltr.io/ubergraph-nonredundant/1.4/query
# Warning Code:405:https://automat.ci.transltr.io/hetio/1.4/query
# Warning Code:405:https://automat.ci.transltr.io/cam-kp/1.4/query?limit=100Warning Code:405:https://automat.ci.transltr.io/ubergraph/1.4/query
#
# Warning Code:404:https://ars-prod.transltr.io/ara-robokop/api/runquery
# Success!https://api.bte.ncats.io/v1/smartapi/59dce17363dce279d389100834e43648/query
# Success!https://api.bte.ncats.io/v1/smartapi/1d288b3a3caf75d541ffaae3aab386c8/query
# Success!https://translator.broadinstitute.org/molepro/trapi/v1.4/query
# Success!https://bte.transltr.io/v1/query
# Success!https://api.bte.ncats.io/v1/smartapi/978fe380a147a8641caf72320862697b/query
# Success!https://api.bte.ncats.io/v1/smartapi/978fe380a147a8641caf72320862697b/query
# UniProtKB:P42771-4no preferred name

# %%
# Step 8: Visualize the results
TCT.visulization_one_hop_ranking(result_ranked_by_primary_infores, 
                                 result_parsed, 
                                 num_of_nodes = 30, 
                                 input_query = input_node1_id,
                                 fontsize = 10,
                                 title_fontsize=12)
# Out:
# UniProtKB:P42771-4no preferred name
# [Text(0.5, 0, 'RAD51'), Text(2.5, 0, 'FANCD2'), Text(4.5, 0, 'TP53'), Text(6.5, 0, 'BCCIP'), Text(8.5, 0, 'KAT2B'), Text(10.5, 0, 'PARP1'), Text(12.5, 0, 'XRCC3'), Text(14.5, 0, 'BRCA1'), Text(16.5, 0, 'RAD51C'), Text(18.5, 0, 'HMG20B'), Text(20.5, 0, 'BUB1B'), Text(22.5, 0, 'PCNA'), Text(24.5, 0, 'CDC45'), Text(26.5, 0, 'H2AX'), Text(28.5, 0, 'KIF4A')]
# [Text(0.5, 0, 'RAD51'), Text(2.5, 0, 'FANCD2'), Text(4.5, 0, 'TP53'), Text(6.5, 0, 'BCCIP'), Text(8.5, 0, 'KAT2B'), Text(10.5, 0, 'PARP1'), Text(12.5, 0, 'XRCC3'), Text(14.5, 0, 'BRCA1'), Text(16.5, 0, 'RAD51C'), Text(18.5, 0, 'HMG20B'), Text(20.5, 0, 'BUB1B'), Text(22.5, 0, 'PCNA'), Text(24.5, 0, 'CDC45'), Text(26.5, 0, 'H2AX'), Text(28.5, 0, 'KIF4A')]
#                                     RAD51  PALB2  FANCD2  SEM1  TP53  EMSY  \
# biolink:homologous_to                   0      0       0     0     0     0
# biolink:regulates                       1      1       1     0     1     0
# biolink:subclass_of                     0      0       0     0     0     0
# biolink:genetically_interacts_with      1      1       1     1     1     1
# biolink:interacts_with                  1      1       1     1     1     1
# biolink:physically_interacts_with       1      1       1     1     1     1
# biolink:affected_by                     0      0       0     0     0     0
# biolink:correlated_with                 0      0       0     0     0     0
# biolink:regulated_by                    1      1       0     1     1     0
# biolink:orthologous_to                  0      0       0     0     0     0
# biolink:has_gene_product                0      0       0     0     0     0
# biolink:coexists_with                   1      1       0     1     1     0
# biolink:associated_with                 1      1       1     1     1     1
# biolink:affects                         1      0       0     0     1     0
#
#                                     BCCIP  BRCC3  KAT2B  PLK1  ...  PIK3CA  \
# biolink:homologous_to                   0      0      0     0  ...       0
# biolink:regulates                       0      0      1     1  ...       0
# biolink:subclass_of                     0      0      0     0  ...       0
# biolink:genetically_interacts_with      1      1      1     1  ...       0
# biolink:interacts_with                  1      1      1     1  ...       1
# biolink:physically_interacts_with       1      1      1     1  ...       0
# biolink:affected_by                     0      0      0     0  ...       0
# biolink:correlated_with                 0      0      0     0  ...       0
# biolink:regulated_by                    0      0      0     1  ...       0
# biolink:orthologous_to                  0      0      0     0  ...       0
# biolink:has_gene_product                0      0      0     0  ...       0
# biolink:coexists_with                   0      0      0     0  ...       0
# biolink:associated_with                 1      1      1     1  ...       1
# biolink:affects                         0      0      0     0  ...       0
#
#                                     CLTB  AKAP13  TOPBP1  UBE2C  POLQ  IRF9  \
# biolink:homologous_to                  0       0       0      0     0     0
# biolink:regulates                      0       0       0      0     0     0
# biolink:subclass_of                    0       0       0      0     0     0
# biolink:genetically_interacts_with     0       0       0      0     0     0
# biolink:interacts_with                 0       0       1      1     0     0
# biolink:physically_interacts_with      0       0       0      1     0     0
# biolink:affected_by                    0       0       0      0     0     0
# biolink:correlated_with                1       1       0      0     0     1
# biolink:regulated_by                   0       0       0      0     0     0
# biolink:orthologous_to                 0       0       0      0     0     0
# biolink:has_gene_product               0       0       0      0     0     0
# biolink:coexists_with                  0       0       0      0     0     0
# biolink:associated_with                0       0       1      1     1     0
# biolink:affects                        0       0       0      0     0     0
#
#                                     PGR  CDKN2A  TLE3
# biolink:homologous_to                 0       0     0
# biolink:regulates                     0       0     0
# biolink:subclass_of                   0       0     0
# biolink:genetically_interacts_with    0       0     0
# biolink:interacts_with                0       1     1
# biolink:physically_interacts_with     0       0     0
# biolink:affected_by                   0       0     0
# biolink:correlated_with               0       0     0
# biolink:regulated_by                  0       0     0
# biolink:orthologous_to                0       0     0
# biolink:has_gene_product              0       0     0
# biolink:coexists_with                 0       0     0
# biolink:associated_with               1       1     0
# biolink:affects                       0       0     0
#
# [14 rows x 605 columns]

# %%
# Step 9: Format query json
query_json2 = TCT.format_query_json(input_node3_list,  # a list of identifiers for input node1
                                   input_node2_list,  # it can be empty list if only want to query node1
                                   input_node3_category,  # a list of categories of input node1
                                   input_node2_category,  # a list of categories of input node2
                                   sele_predicates_2) # a list of predicates

# %%
# Step 10: Query Translator APIs and parse results
result2 = TCT.parallel_api_query(API_URLs_2,query_json=query_json2, max_workers=len(API_URLs_2))

# Step 11: Parse results
result_parsed2 = TCT.parse_KG(result2)

# Step 12: Ranking the results. This ranking method is based on the number of unique primary infores. It can only be used to rank the results with one defined node.
result_ranked_by_primary_infores2 = TCT.rank_by_primary_infores(result_parsed2, input_node3_id)   # input_node1_id is the curie id of the input node, such as "NCBIGene:672"
# Out:
# '' generated an exception: Invalid URL '': No scheme supplied. Perhaps you meant https://?
# '' generated an exception: Invalid URL '': No scheme supplied. Perhaps you meant https://?
# '' generated an exception: Invalid URL '': No scheme supplied. Perhaps you meant https://?
# Warning Code:404:https://api.bte.ncats.io/v1/8f08d1446e0bb9c2b323713ce83e2bd3/query
# Warning Code:404:https://api.bte.ncats.io/v1/bde72db681ec0b8f9eeb67bb6b8dd72c/query
# 'https://automat.ci.renci.org/drugcentral/1.4/query' generated an exception: HTTPSConnectionPool(host='automat.ci.renci.org', port=443): Max retries exceeded with url: /drugcentral/1.4/query (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1400fe710>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Warning Code:503:https://bte.test.transltr.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query
# Warning Code:404:https://automat.renci.org/biolink/1.4/query
# Warning Code:405:https://automat.renci.org/hmdb/1.4/query
# Warning Code:404:https://automat.ci.transltr.io/ubergraph-nonredundant/1.4/query
# Warning Code:405:https://automat.renci.org/icees-kg/1.4/query
# Warning Code:404:https://ars-prod.transltr.io/ara-robokop/api/runquery
# Warning Code:405:https://automat.renci.org/pharos/1.4/query
# Warning Code:405:https://automat.renci.org/gtopdb/1.4/query
# Warning Code:405:https://automat.ci.transltr.io/cam-kp/1.4/query?limit=100
# Warning Code:405:https://automat.ci.transltr.io/ctd/1.4/queryWarning Code:405:https://automat.ci.transltr.io/ubergraph/1.4/queryWarning Code:405:https://automat.ci.transltr.io/hetio/1.4/query
#
#
# Success!https://api.bte.ncats.io/v1/smartapi/e3edd325c76f2992a111b43a907a4870/query
# Success!https://api.bte.ncats.io/v1/smartapi/38e9e5169a72aee3659c9ddba956790d/query
# Success!https://api.bte.ncats.io/v1/smartapi/edeb26858bd27d0322af93e7a9e08761/query
# Success!https://api.bte.ncats.io/v1/smartapi/1d288b3a3caf75d541ffaae3aab386c8/query
# Success!https://translator.broadinstitute.org/molepro/trapi/v1.4/query
# Success!https://bte.transltr.io/v1/query
# Success!https://api.bte.ncats.io/v1/smartapi/978fe380a147a8641caf72320862697b/query
# Success!https://api.bte.ncats.io/v1/smartapi/978fe380a147a8641caf72320862697b/query
# Success!https://api.bte.ncats.io/v1/smartapi/978fe380a147a8641caf72320862697b/query
# Success!https://api.bte.ncats.io/v1/smartapi/02af7d098ab304e80d6f4806c3527027/query
# UniProtKB:Q9UGN5-1no preferred name
# TTD.TARGET:T17228no preferred name
# TTD.TARGET:T83059no preferred name
# TTD.TARGET:T34867no preferred name
# UniProtKB:P42166-1no preferred name
# UniProtKB:Q9BXH1-2no preferred name

# %%
# Step 13: Visualize the results
TCT.visulization_one_hop_ranking(result_ranked_by_primary_infores2, result_parsed2, num_of_nodes = 30, 
                                 input_query = input_node3_id,
                                 fontsize = 10,
                                 title_fontsize=12)
# Out:
# UniProtKB:P42166-1no preferred name
# UniProtKB:Q9BXH1-2no preferred name
# UniProtKB:Q9UGN5-1no preferred name
# TTD.TARGET:T17228no preferred name
# TTD.TARGET:T83059no preferred name
# TTD.TARGET:T34867no preferred name
# [Text(0.5, 0, 'PARP1'), Text(2.5, 0, 'PARP3'), Text(4.5, 0, 'TNKS2'), Text(6.5, 0, 'PARP1_HUMAN Poly [ADP-ribose] polymerase 1 (sprot)'), Text(8.5, 0, 'PARP15'), Text(10.5, 0, 'TNKS2_HUMAN Poly [ADP-ribose] polymerase tankyrase-2 (sprot)'), Text(12.5, 0, 'CHEK1'), Text(14.5, 0, 'PARP16'), Text(16.5, 0, 'CHEK2'), Text(18.5, 0, 'PARP12'), Text(20.5, 0, 'CDK12'), Text(22.5, 0, 'TNKS1_HUMAN Poly [ADP-ribose] polymerase tankyrase-1 (sprot)'), Text(24.5, 0, 'AKT1'), Text(26.5, 0, 'BAX'), Text(28.5, 0, 'RAD51')]
# [Text(0.5, 0, 'PARP1'), Text(2.5, 0, 'PARP3'), Text(4.5, 0, 'TNKS2'), Text(6.5, 0, 'PARP1_HUMAN Poly [ADP-ribose] polymerase 1 (sprot)'), Text(8.5, 0, 'PARP15'), Text(10.5, 0, 'TNKS2_HUMAN Poly [ADP-ribose] polymerase tankyrase-2 (sprot)'), Text(12.5, 0, 'CHEK1'), Text(14.5, 0, 'PARP16'), Text(16.5, 0, 'CHEK2'), Text(18.5, 0, 'PARP12'), Text(20.5, 0, 'CDK12'), Text(22.5, 0, 'TNKS1_HUMAN Poly [ADP-ribose] polymerase tankyrase-1 (sprot)'), Text(24.5, 0, 'AKT1'), Text(26.5, 0, 'BAX'), Text(28.5, 0, 'RAD51')]
#                                             PARP1  PARP2  PARP3  TNKS  TNKS2  \
# biolink:occurs_together_in_literature_with      1      1      1     1      1
# biolink:has_substrate                           0      0      0     0      0
# biolink:binds                                   1      1      0     0      0
# biolink:is_substrate_of                         0      0      0     0      0
# biolink:interacts_with                          1      1      1     1      1
# biolink:physically_interacts_with               1      1      1     1      1
# biolink:affected_by                             0      0      0     0      0
# biolink:correlated_with                         0      0      0     0      0
# biolink:directly_physically_interacts_with      0      1      0     0      0
# biolink:related_to                              1      1      0     0      0
# biolink:assesses                                0      0      0     0      0
# biolink:affects                                 1      1      1     1      1
#
#                                             PARP4  \
# biolink:occurs_together_in_literature_with      1
# biolink:has_substrate                           0
# biolink:binds                                   0
# biolink:is_substrate_of                         0
# biolink:interacts_with                          0
# biolink:physically_interacts_with               1
# biolink:affected_by                             0
# biolink:correlated_with                         0
# biolink:directly_physically_interacts_with      0
# biolink:related_to                              0
# biolink:assesses                                0
# biolink:affects                                 1
#
#                                             PARP1_HUMAN Poly [ADP-ribose] polymerase 1 (sprot)  \
# biolink:occurs_together_in_literature_with                                                  0
# biolink:has_substrate                                                                       0
# biolink:binds                                                                               1
# biolink:is_substrate_of                                                                     0
# biolink:interacts_with                                                                      0
# biolink:physically_interacts_with                                                           0
# biolink:affected_by                                                                         0
# biolink:correlated_with                                                                     0
# biolink:directly_physically_interacts_with                                                  1
# biolink:related_to                                                                          1
# biolink:assesses                                                                            1
# biolink:affects                                                                             1
#
#                                             TP53  PARP15  \
# biolink:occurs_together_in_literature_with     1       1
# biolink:has_substrate                          0       0
# biolink:binds                                  0       0
# biolink:is_substrate_of                        0       0
# biolink:interacts_with                         1       0
# biolink:physically_interacts_with              0       1
# biolink:affected_by                            0       0
# biolink:correlated_with                        1       0
# biolink:directly_physically_interacts_with     0       0
# biolink:related_to                             1       0
# biolink:assesses                               0       0
# biolink:affects                                1       1
#
#                                             PARP2_HUMAN Poly [ADP-ribose] polymerase 2 (sprot)  \
# biolink:occurs_together_in_literature_with                                                  0
# biolink:has_substrate                                                                       0
# biolink:binds                                                                               1
# biolink:is_substrate_of                                                                     0
# biolink:interacts_with                                                                      0
# biolink:physically_interacts_with                                                           0
# biolink:affected_by                                                                         0
# biolink:correlated_with                                                                     0
# biolink:directly_physically_interacts_with                                                  0
# biolink:related_to                                                                          1
# biolink:assesses                                                                            1
# biolink:affects                                                                             1
#
#                                             ...  EPHA3  CFD  HADHA  HNF4A  \
# biolink:occurs_together_in_literature_with  ...      0    0      0      0
# biolink:has_substrate                       ...      0    0      0      0
# biolink:binds                               ...      0    0      0      0
# biolink:is_substrate_of                     ...      0    0      0      0
# biolink:interacts_with                      ...      0    0      0      0
# biolink:physically_interacts_with           ...      0    0      0      0
# biolink:affected_by                         ...      0    0      0      0
# biolink:correlated_with                     ...      1    1      1      1
# biolink:directly_physically_interacts_with  ...      0    0      0      0
# biolink:related_to                          ...      0    0      0      0
# biolink:assesses                            ...      0    0      0      0
# biolink:affects                             ...      0    0      0      0
#
#                                             CTSK  LGR4  IDH1  LGALS3  C1S  \
# biolink:occurs_together_in_literature_with     0     0     0       0    0
# biolink:has_substrate                          0     0     0       0    0
# biolink:binds                                  0     0     0       0    0
# biolink:is_substrate_of                        0     0     0       0    0
# biolink:interacts_with                         0     0     1       0    0
# biolink:physically_interacts_with              0     0     0       0    0
# biolink:affected_by                            0     0     0       0    0
# biolink:correlated_with                        1     1     0       1    1
# biolink:directly_physically_interacts_with     0     0     0       0    0
# biolink:related_to                             0     0     0       0    0
# biolink:assesses                               0     0     0       0    0
# biolink:affects                                0     0     1       0    0
#
#                                             NHEJ1
# biolink:occurs_together_in_literature_with      1
# biolink:has_substrate                           0
# biolink:binds                                   0
# biolink:is_substrate_of                         0
# biolink:interacts_with                          0
# biolink:physically_interacts_with               0
# biolink:affected_by                             0
# biolink:correlated_with                         0
# biolink:directly_physically_interacts_with      0
# biolink:related_to                              0
# biolink:assesses                                0
# biolink:affects                                 0
#
# [12 rows x 837 columns]

# %%
# Find possible paths
possible_paths = len(set(result_ranked_by_primary_infores['output_node']).intersection(set(result_ranked_by_primary_infores2['output_node'])))
print("Number of possible paths: ", possible_paths)
# Out:
# Number of possible paths:  128

# %%
TCT.merge_ranking_by_number_of_infores(result_ranked_by_primary_infores, result_ranked_by_primary_infores2, 
                                       top_n = 30,
                                       fontsize=10,
                                       title_fontsize=12,)
# Out:
#                                          score       output_node  \
# PARP1                                 0.800000      NCBIGene:142
# TP53                                  0.384615     NCBIGene:7157
# PARP2                                 0.369231    NCBIGene:10038
# RAD51                                 0.230769     NCBIGene:5888
# CHEK2                                 0.184615    NCBIGene:11200
# ...                                        ...               ...
# PGR                                   0.015385     NCBIGene:5241
# SAMHD1                                0.015385    NCBIGene:25939
# ANDR_HUMAN Androgen receptor (sprot)  0.015385  UniProtKB:P10275
# MSH2                                  0.015385     NCBIGene:4436
# MSH3                                  0.015385     NCBIGene:4437
#
#                                                                              predictes1  \
# PARP1                                 biolink:regulates\nbiolink:genetically_interac...
# TP53                                  biolink:regulates\nbiolink:genetically_interac...
# PARP2                                 biolink:genetically_interacts_with\nbiolink:in...
# RAD51                                 biolink:regulates\nbiolink:genetically_interac...
# CHEK2                                 biolink:genetically_interacts_with\nbiolink:in...
# ...                                                                                 ...
# PGR                                                             biolink:associated_with
# SAMHD1                                                                biolink:regulates
# ANDR_HUMAN Androgen receptor (sprot)            biolink:regulates\nbiolink:regulated_by
# MSH2                                    biolink:interacts_with\nbiolink:associated_with
# MSH3                                    biolink:interacts_with\nbiolink:associated_with
#
#                                                                              predictes2  \
# PARP1                                 biolink:affects\nbiolink:affects\nbiolink:affe...
# TP53                                  biolink:affects\nbiolink:correlated_with\nbiol...
# PARP2                                 biolink:affects\nbiolink:directly_physically_i...
# RAD51                                 biolink:affects\nbiolink:affects\nbiolink:rela...
# CHEK2                                 biolink:affects\nbiolink:affects\nbiolink:occu...
# ...                                                                                 ...
# PGR                                                              biolink:interacts_with
# SAMHD1                                                                  biolink:affects
# ANDR_HUMAN Androgen receptor (sprot)                                    biolink:affects
# MSH2                                                                 biolink:related_to
# MSH3                                            biolink:affected_by\nbiolink:related_to
#
#                                                           output_node_name
# PARP1                                                                PARP1
# TP53                                                                  TP53
# PARP2                                                                PARP2
# RAD51                                                                RAD51
# CHEK2                                                                CHEK2
# ...                                                                    ...
# PGR                                                                    PGR
# SAMHD1                                                              SAMHD1
# ANDR_HUMAN Androgen receptor (sprot)  ANDR_HUMAN Androgen receptor (sprot)
# MSH2                                                                  MSH2
# MSH3                                                                  MSH3
#
# [128 rows x 5 columns]

# %%
t2 = TCT.merge_by_ranking_index(result_ranked_by_primary_infores,
                           result_ranked_by_primary_infores2, 
                           top_n=30, fontsize=10, 
                           title_fontsize=12)

# %%
TCT.visulize_path(input_node1_id, TCT.get_curie("PARP1"), input_node3_id, result, result2)
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'cola', 'title': 'Path', 'nodeSpacing': 80, 'edgeLengthVal': 50}, cy…
#                       Subject        Object  \
# 0                NCBIGene:675  NCBIGene:142
# 1                NCBIGene:675  NCBIGene:142
# 2                NCBIGene:675  NCBIGene:142
# 4                NCBIGene:675  NCBIGene:142
# 7                NCBIGene:675  NCBIGene:142
# 8                NCBIGene:675  NCBIGene:142
# 9                NCBIGene:675  NCBIGene:142
# 10  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 11  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 12  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 13  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 14  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 15  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 17  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 19  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 20  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 22  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 24  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 25  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 26  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 28  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 30  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 31  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 32  PUBCHEM.COMPOUND:23725625  NCBIGene:142
# 33  PUBCHEM.COMPOUND:23725625  NCBIGene:142
#
#                                            Predicates Subject_name Object_name
# 0                           affects::infores:semmeddb        BRCA2       PARP1
# 1                     associated_with::infores:string        BRCA2       PARP1
# 2    regulates::infores:text-mining-provider-targeted        BRCA2       PARP1
# 4   regulated_by::infores:text-mining-provider-tar...        BRCA2       PARP1
# 7         genetically_interacts_with::infores:biogrid        BRCA2       PARP1
# 8                     interacts_with::infores:biogrid        BRCA2       PARP1
# 9                      interacts_with::infores:string        BRCA2       PARP1
# 10                               affects::infores:ctd     Olaparib       PARP1
# 11                            affects::infores:gtopdb     Olaparib       PARP1
# 12                            affects::infores:chembl     Olaparib       PARP1
# 13                          affects::infores:drugbank     Olaparib       PARP1
# 14              affects::infores:drug-repurposing-hub     Olaparib       PARP1
# 15                             affects::infores:dgidb     Olaparib       PARP1
# 17                       affects::infores:drugcentral     Olaparib       PARP1
# 19                            affects::infores:pharos     Olaparib       PARP1
# 20                              binds::infores:pharos     Olaparib       PARP1
# 22                      interacts_with::infores:dgidb     Olaparib       PARP1
# 24                        interacts_with::infores:ttd     Olaparib       PARP1
# 25       physically_interacts_with::infores:bindingdb     Olaparib       PARP1
# 26     affects::infores:text-mining-provider-targeted     Olaparib       PARP1
# 28                            related_to::infores:ctd     Olaparib       PARP1
# 30     physically_interacts_with::infores:drugcentral     Olaparib       PARP1
# 31                     interacts_with::infores:chembl     Olaparib       PARP1
# 32                          affects::infores:semmeddb     Olaparib       PARP1
# 33  occurs_together_in_literature_with::infores:pfocr     Olaparib       PARP1
